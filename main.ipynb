# %%
import random
from collections import deque

# Define card ranks and suits
RANKS = '34567890JQKA2'  # '0' represents 10
SUITS = 'CDHS'  # Clubs, Diamonds, Hearts, Spades (Spades highest)

# %%
class Card:
    def __init__(self, rank, suit):
        self.rank = rank
        self.suit = suit

    def __repr__(self):
        return f"{self.rank}{self.suit}"

    def value(self):
        return (RANKS.index(str(self.rank)), SUITS.index(self.suit))

    @classmethod
    def from_string(cls, card_str):
        """Create a Card object from a string like '3D' or '2S'."""
        if len(card_str) != 2:
            raise ValueError("Invalid card format! Use format like '3D', '2S', or '0C'.")
        rank, suit = card_str[0], card_str[1]  # Extract rank and suit
        if rank not in cls.RANKS or suit not in cls.SUITS:
            raise ValueError(f"Invalid card: {card_str}")
        return cls(rank, suit)

# %%
class Player:
    def __init__(self, player_id):
        self.player_id = player_id
        self.hand = deque()  # Player's hand as a deque

    def add_card(self, card):
        """Add a card to the player's hand and keep it sorted."""
        self.hand.append(card)
        self.hand = deque(sorted(self.hand, key=lambda c: c.value()))

    def remove_card(self, card):
        """Remove a specific card from the player's hand."""
        for c in self.hand:
            if c.rank == card.rank and c.suit == card.suit:
                self.hand.remove(c)
                return True  # Successfully removed
        print(f"{card} is not in player {self.player_id}'s hand!")
        return False

    def has_card(self, rank, suit):
        """Check if the player has a specific card."""
        return any(c.rank == rank and c.suit == suit for c in self.hand)

    def get_sorted_hand(self):
        """Return a sorted list of the player's hand."""
        return sorted(self.hand, key=lambda c: c.value())

    def is_hand_empty(self):
        """Check if the player has no more cards."""
        return len(self.hand) == 0

# %%
class BigTwoGame:
    def __init__(self):
        self.players = [Player(i) for i in range(4)]  # 4 player objects
        self.last_play = None  # Track the last valid play
        self.last_played_by = None  # Track the last player who played a card
        self.pass_count = 0  # Track how many players passed in a row
        self.create_deck()
        self.deal_cards()
        self.current_player = self.determine_starting_player()  # Player with 3C starts
        self.round = 0
        self.first_move = True

    def create_deck(self):
        self.deck = [Card(rank, suit) for rank in RANKS for suit in SUITS]
        random.shuffle(self.deck)

    def deal_cards(self):
        for i, card in enumerate(self.deck):
            self.players[i % 4].add_card(card)  # Add card to Player object

    def determine_starting_player(self):
        """Finds the player who has 3C and returns their index."""
        for player in self.players:
            if player.has_card('3', 'C'):
                return player.player_id
        return 0  # Fallback, should never happen

    def current_turn(self):
        """Returns the player index whose turn it is."""
        return self.current_player

    def has_valid_move(self, player_index):
        """Check if the player has any valid move."""
        player = self.players[player_index]
        return any(self.validate_move(player_index, card) for card in player.hand)

    def find_playable_cards(self, player_index):
        """Returns a list of all playable single cards for the given player."""
        player = self.players[player_index]

        if (self.round == 0 and self.first_move):
            return [card for card in player.hand if card.rank == '3' and card.suit == 'C']
        
        if not self.last_play:
            return player.hand
            
        return [card for card in player.hand if card.value() > self.last_play.value()]
    
    def play_turn(self, player_index, play):
        """Handles a player's move. 'play' is a single card or 'pass'."""
        if player_index != self.current_player:
            print(f"Not your turn! It's Player {self.current_player}'s turn.")
            return
            
        if play == "pass":
            self.pass_count += 1
            print(f"Player {player_index} passes.")

            if self.pass_count == 3:
                print("All players passed! New round starts.")
                self.last_play = None
                self.pass_count = 0
                self.round += 1
        else:
            valid_move = self.validate_move(player_index, play)
            if valid_move:
                self.players[player_index].remove_card(play)
                self.last_play = play
                self.last_played_by = player_index
                self.pass_count = 0
                print(f"Player {player_index} plays {play}")

                if (play.rank == '3' and play.suit == 'C'):
                    self.first_move = False
            else:
                print("Invalid move!")
                return
                
        self.next_player()

    def validate_move(self, player_index, play):
        """Checks if the move follows Big Two rules."""
        if self.round == 0 and self.first_move:
            return play.rank == '3' and play.suit == 'C'

        if self.last_play != None:
            return play.value() > self.last_play.value()
        
        return True
    
    def next_player(self):
        self.current_player = (self.current_player + 1) % 4
    
    def is_game_over(self):
        return any(player.is_hand_empty() for player in self.players)

    def return_hand(self, player_index):
        if player_index not in range(4):
            print("There are only 4 players")
            return None
            
        return self.players[player_index].get_sorted_hand()

    def print_hands(self):
        for player in self.players:
            print(f"Player {player.player_id}: {player.get_sorted_hand()}")

# %% [raw]
# class BigTwoGame2:
#     def __init__(self):
#         self.players = [deque() for _ in range(4)]  # 4 players, hands as deques
#         self.last_play = None  # Track the last valid play
#         self.create_deck()
#         self.deal_cards()
#         self.current_player = self.determine_starting_player()  # Player with 3C starts
#
#     def create_deck(self):
#         self.deck = [Card(rank, suit) for rank in RANKS for suit in SUITS]
#         random.shuffle(self.deck)
#
#     def deal_cards(self):
#         for i, card in enumerate(self.deck):
#             self.players[i % 4].append(card)
#         for player in self.players:
#             player = sorted(player, key=lambda c: c.value())  # Sort hands
#
#     def determine_starting_player(self):
#         """Finds the player who has 3C and returns their index."""
#         for i, hand in enumerate(self.players):
#             for card in hand:
#                 if card.rank == '3' and card.suit == 'C':
#                     return i
#         return 0  # Fallback, should never happen
#
#     def current_turn(self):
#         """Returns the player index whose turn it is."""
#         return self.current_player
#
#     def has_valid_move(self, player_index):
#         """Iterates through all cards in hand and calls validate_move."""
#         hand = self.players[player_index]
#
#         # Try every single card in hand as a move
#         for card in hand:
#             if self.validate_move(player_index, card):  # Play single card
#                 return True  # Valid move found
#
#         return False  # No valid move found
#
#     def play_turn(self, player_index, play):
#         """Handles a player's move. 'play' is a list of cards or 'pass'."""
#         if player_index != self.current_player:
#             print(f"Not your turn! It's Player {self.current_player}'s turn.")
#             return
#
#         if not self.last_play and (play == "pass" or (play.rank != '3' or play.suit != 'C')):
#             print("First move must include 3C!")
#             return  # Do not allow passing or playing anything else first
#
#         if play == "pass":
#             print(f"Player {player_index} passes.")
#         else:
#             valid_move = self.validate_move(player_index, play)
#             if valid_move:
#                 self.remove_card(player_index, play)
#                 self.last_play = play
#                 print(f"Player {player_index} plays {play}")
#             else:
#                 print("Invalid move!")
#                 return
#
#         self.next_player()
#
#     def remove_card(self, player_index, card):
#         """Removes a card from a player's hand safely."""
#         for c in self.players[player_index]:
#             if c.rank == card.rank and c.suit == card.suit:
#                 self.players[player_index].remove(c)
#                 return True  # Successfully removed
#         print(f"{card} is not in player {player_index}'s hand!")
#         return False
#
#     def validate_move(self, player_index, play):
#         """Checks if the move follows Big Two rules."""
#
#         # First move must include 3C
#         if not self.last_play:
#             return play.rank == '3' and play.suit == 'C'
#
#         return play.value() > self.last_play.value()
#
#     def next_player(self):
#         self.current_player = (self.current_player + 1) % 4
#
#     def is_game_over(self):
#         return any(len(player) == 0 for player in self.players)
#
#     def return_hand(self, player_index):
#         if player_index not in [0, 1, 2, 3]:
#             print("There are only 4 players")
#             return None
#         return sorted(self.players[player_index], key=lambda c: c.value())
#
#     def print_hands(self):
#         for i, hand in enumerate(self.players):
#             print(f"Player {i}: {sorted(hand, key=lambda c: c.value())}")

# %%
game = BigTwoGame()

round = game.round
while (round < 20):
    player = game.current_player
    
    print(f"Round {round}")
    print(f"Player {player}'s turn")
    game.print_hands()

    playable_cards = game.find_playable_cards(player)
    if (len(playable_cards) > 0):
        game.play_turn(player, random.choice(playable_cards))
    else:
        game.play_turn(player, "pass")

    round = game.round

    if (game.is_game_over() == True):
        winner = game.last_played_by
        print(f"Game over. The winner is player {winner}")
        break

    print("\n")
# Out:
# Round 0
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2H, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AC, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H, AD]
# Player 3 passes.
#
#
# Round 0
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2H, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AC, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H, AD]
# Player 0 passes.
#
#
# Round 0
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2H, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AC, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H, AD]
# Player 1 passes.
# All players passed! New round starts.
#
#
# Round 1
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2H, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AC, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H, AD]
# Player 2 plays AC
#
#
# Round 1
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2H, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H, AD]
# Player 3 plays AD
#
#
# Round 1
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2H, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays 2H
#
#
# Round 1
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 passes.
#
#
# Round 1
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 passes.
#
#
# Round 1
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
# All players passed! New round starts.
#
#
# Round 2
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QC, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays QC
#
#
# Round 2
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH, 2C]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays 2C
#
#
# Round 2
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS, 2D]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays 2D
#
#
# Round 2
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
#
#
# Round 2
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS, 2S]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays 2S
#
#
# Round 2
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 passes.
#
#
# Round 2
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 passes.
#
#
# Round 2
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
# All players passed! New round starts.
#
#
# Round 3
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QD, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays QD
#
#
# Round 3
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, KH, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays KH
#
#
# Round 3
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS, AS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays AS
#
#
# Round 3
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
#
#
# Round 3
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 passes.
#
#
# Round 3
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 passes.
# All players passed! New round starts.
#
#
# Round 4
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays 5C
#
#
# Round 4
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8D, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 plays 8D
#
#
# Round 4
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, QH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays QH
#
#
# Round 4
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD, AH]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays AH
#
#
# Round 4
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 passes.
#
#
# Round 4
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
#
#
# Round 4
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 passes.
# All players passed! New round starts.
#
#
# Round 5
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 3S, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays 3S
#
#
# Round 5
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5D, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays 5D
#
#
# Round 5
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 5S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 plays 5S
#
#
# Round 5
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, 7H, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays 7H
#
#
# Round 5
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 9S, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays 9S
#
#
# Round 5
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, JS, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays JS
#
#
# Round 5
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
#
#
# Round 5
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KC, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays KC
#
#
# Round 5
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD, KD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays KD
#
#
# Round 5
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 passes.
#
#
# Round 5
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
#
#
# Round 5
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, JH, KS]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays KS
#
#
# Round 5
# Player 1's turn
# Player 1: [4D, 4H, 6D, 7C, JH]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 passes.
#
#
# Round 5
# Player 2's turn
# Player 1: [4D, 4H, 6D, 7C, JH]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 passes.
#
#
# Round 5
# Player 3's turn
# Player 1: [4D, 4H, 6D, 7C, JH]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
# All players passed! New round starts.
#
#
# Round 6
# Player 0's turn
# Player 1: [4D, 4H, 6D, 7C, JH]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 plays 6D
#
#
# Round 6
# Player 1's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 7D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 plays 7D
#
#
# Round 6
# Player 2's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C, QS]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays QS
#
#
# Round 6
# Player 3's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 passes.
#
#
# Round 6
# Player 0's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 0 passes.
#
#
# Round 6
# Player 1's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 1 passes.
# All players passed! New round starts.
#
#
# Round 7
# Player 2's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [3C, 4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 2 plays 3C
#
#
# Round 7
# Player 3's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D, 0H]
# Player 3 plays 0H
#
#
# Round 7
# Player 0's turn
# Player 1: [4D, 4H, 7C, JH]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 0 plays JH
#
#
# Round 7
# Player 1's turn
# Player 1: [4D, 4H, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 1 passes.
#
#
# Round 7
# Player 2's turn
# Player 1: [4D, 4H, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 2 passes.
#
#
# Round 7
# Player 3's turn
# Player 1: [4D, 4H, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 3 passes.
# All players passed! New round starts.
#
#
# Round 8
# Player 0's turn
# Player 1: [4D, 4H, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 0 plays 4H
#
#
# Round 8
# Player 1's turn
# Player 1: [4D, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC, JD]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 1 plays JD
#
#
# Round 8
# Player 2's turn
# Player 1: [4D, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 2 passes.
#
#
# Round 8
# Player 3's turn
# Player 1: [4D, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 3 passes.
#
#
# Round 8
# Player 0's turn
# Player 1: [4D, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 0 passes.
# All players passed! New round starts.
#
#
# Round 9
# Player 1's turn
# Player 1: [4D, 7C]
# Player 2: [3D, 8C, 9D, 0S, JC]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 1 plays 3D
#
#
# Round 9
# Player 2's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, 0S, JC]
# Player 3: [4C, 5H, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 2 plays 5H
#
#
# Round 9
# Player 3's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, 0S, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 8S, 9H, 0C, 0D]
# Player 3 plays 8S
#
#
# Round 9
# Player 0's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, 0S, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 0 passes.
#
#
# Round 9
# Player 1's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, 0S, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 1 plays 0S
#
#
# Round 9
# Player 2's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 2 passes.
#
#
# Round 9
# Player 3's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 3 passes.
#
#
# Round 9
# Player 0's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 0 passes.
# All players passed! New round starts.
#
#
# Round 10
# Player 1's turn
# Player 1: [4D, 7C]
# Player 2: [8C, 9D, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 1 plays 9D
#
#
# Round 10
# Player 2's turn
# Player 1: [4D, 7C]
# Player 2: [8C, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 2 passes.
#
#
# Round 10
# Player 3's turn
# Player 1: [4D, 7C]
# Player 2: [8C, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0C, 0D]
# Player 3 plays 0C
#
#
# Round 10
# Player 0's turn
# Player 1: [4D, 7C]
# Player 2: [8C, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0D]
# Player 0 passes.
#
#
# Round 10
# Player 1's turn
# Player 1: [4D, 7C]
# Player 2: [8C, JC]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0D]
# Player 1 plays JC
#
#
# Round 10
# Player 2's turn
# Player 1: [4D, 7C]
# Player 2: [8C]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0D]
# Player 2 passes.
#
#
# Round 10
# Player 3's turn
# Player 1: [4D, 7C]
# Player 2: [8C]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0D]
# Player 3 passes.
#
#
# Round 10
# Player 0's turn
# Player 1: [4D, 7C]
# Player 2: [8C]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0D]
# Player 0 passes.
# All players passed! New round starts.
#
#
# Round 11
# Player 1's turn
# Player 1: [4D, 7C]
# Player 2: [8C]
# Player 3: [4C, 6C, 7S, 9C]
# Player 4: [3H, 4S, 6H, 6S, 8H, 9H, 0D]
# Player 1 plays 8C
# Game over. The winner is player 1
